# %%
# dấu # dùng để ghi chú
# Shift + Enter: Run code và thêm 1 dòng mới

# %%
# Ctrl + Enter: Run code nhưng không add new line

# %%
# !pip install pillow

# %%
# Thêm thư viện
from PIL import Image

# %%
# Khai báo một biến chứa thư mục
dir = 'C:/Users/DELL/baitap_thigiacmaytinh/hien/thigiacmaytinh/lib'

# %%
# Khai báo đường dẫn ảnh
image_path = dir + "/01.JPG"
print(image_path)
# Out:
# C:/Users/DELL/baitap_thigiacmaytinh/hien/thigiacmaytinh/lib/01.JPG

# %%
# Sử dụng Image.open(image_path) để đọc ảnh
img01 = Image.open(image_path)

# %%
# Hiển thị hình ảnh
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x853>

# %%
# In thông tin cơ bản
print("Kích cỡ ảnh: ", img01.size)
# Out:
# Kích cỡ ảnh:  (1280, 853)

# %%
# Lưu ảnh và chuyển đổi ảnh
new_img_01_path = dir + "/new_01.jpg"
new_img_PNG_01_path = dir + "/new_01.png"
img01.save(new_img_01_path)
img01.save(new_img_PNG_01_path)

# %%
# Đóng tập tin
img01.close()
